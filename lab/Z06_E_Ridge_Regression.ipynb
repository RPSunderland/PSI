# %% [markdown]
# # Ridge Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn import linear_model
import scipy.stats as stats
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection

# %% [markdown]
# Rozważmy następujący zbiór punktów:

# %%
true_fun = lambda X: np.cos(1.5 * np.pi * X)
n_samples=20
x = np.sort(np.random.rand(n_samples))
y = true_fun(x) + np.random.randn(n_samples) * 0.1
x=np.vstack(x)

# %% [markdown]
# # Przykład
# Proszę wykonać regresję (Ridge Regression) na powyższym zbiorze danych

# %%
clf = Ridge(alpha=1.0)
clf.fit(x, y) 

x_plot = np.vstack(np.linspace(0, 1, 20))
plt.plot(x_plot, clf.predict(x_plot), color='blue',linewidth=3)
plt.plot(x, y, 'ok');
plt.show()

# %% [markdown]
# ## Regresja liniowa

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
x_plot = np.vstack(np.linspace(-3, 3, 1000))
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 2
# LR degree 20

# %% [markdown]
# # Zadanie
# Proszę wykonać
# * regresję dla wielomianów o stopniu **20**
# * regresję (Ridge Regression) dla wielomianów o stopniu **20** oraz
#    * alpha = 1
#    * alpha = 10 000
#    * alpha = 0.0001

# %%
models = []
predicts = []
names = []
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))
models.append(('Ridge degree 20, alpha=1', make_pipeline(PolynomialFeatures(20), Ridge(alpha=1)) ))
models.append(('Ridge degree 20, alpha=10000', make_pipeline(PolynomialFeatures(20), Ridge(alpha=10000)) ))
models.append(('Ridge degree 20, alpha=0.0001', make_pipeline(PolynomialFeatures(20), Ridge(alpha=0.0001)) ))  

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
plt.plot(x, y, 'ok');
for i in range(len(models)):
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr alpha za pomocą komendy **GridSearchCV**.

# %%
from sklearn.model_selection import GridSearchCV

seed=123
kfold = model_selection.KFold(n_splits=10, random_state=seed)
scoring = 'neg_mean_absolute_error'
results = []


grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=3), Ridge()), param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7], 'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000]},
                    cv=kfold,
                    refit=False)
grid.fit(x, y)
grid.best_params_
# Out:
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# {'polynomialfeatures__degree': 4, 'ridge__alpha': 0.001}

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr <tt>alpha</tt> za pomocą metody <tt>GridSearchCV</tt> dla danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.
#
# *  policz r_square score.

# %%
import pandas as pd
df_adv = pd.read_csv('https://raw.githubusercontent.com/przem85/bootcamp/master/statistics/Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=3), Ridge()), 
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7], 
                                'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000]},
                    cv=kfold,
                    refit=False)
grid.fit(X, y)
best_params = grid.best_params_
best_params
# Out:
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.53913e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.27179e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.52164e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.49028e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.64099e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.04032e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.69818e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.4927e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.75146e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.15593e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.53913e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.27179e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.52164e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.49028e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.64099e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.04032e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.69818e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.4927e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.75146e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.15593e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.53913e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.27179e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.52164e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.49028e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.64099e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.04032e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.69818e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.4927e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.75146e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.15593e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.53913e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.27179e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.52164e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.49028e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.64099e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.04032e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.69818e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.4927e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.75146e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.15593e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09603e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.20867e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09957e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.08247e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.11734e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.182e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.10802e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.0909e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.136e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.19909e-24): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09603e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.20867e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09957e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.08247e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.11734e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.182e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.10802e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.0909e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.136e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.19909e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09603e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.20867e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09957e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.08247e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.11734e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.182e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.10802e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.0909e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.136e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.19909e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09603e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.20867e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09957e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.08247e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.11734e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.182e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.10802e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.0909e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.136e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.19909e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09603e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.20867e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09957e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.08247e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.11734e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.182e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.10802e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.0909e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.136e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.19909e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09603e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.20867e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.09957e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.08247e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.11734e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.182e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.10802e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.0909e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.136e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.19909e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.07938e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.14406e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.03671e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.02578e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.0561e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.12168e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.04986e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.04755e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.07004e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.12943e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.40002e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.56017e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.41337e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.3735e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.43374e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.53411e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.40624e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.39251e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.46116e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.55693e-29): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.40002e-28): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.56017e-28): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.41337e-28): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.3735e-28): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.43374e-28): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.53411e-28): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.40624e-28): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.39251e-28): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1