# %% [markdown]
# # Regresja

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import cross_val_predict
from sklearn import linear_model
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Rozważmy zbiór Boston

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
boston = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# %%
# get the data
boston_X = np.hstack([boston.values[::2, :], boston.values[1::2, :2]])
boston_Y = boston.values[1::2, 2]

# %% [markdown]
# Podzielmy zbiór na część testową i treningową .

# %%
# Split the data into training/testing sets
boston_X_train = boston_X[:-50]
boston_X_test = boston_X[-50:]
 
# Split the targets into training/testing sets
boston_y_train = boston_Y[:-50]
boston_y_test = boston_Y[-50:]

# %%
X=boston_X_train
y=boston_y_train

# %% [markdown]
# # Zadanie
# Znajdż najleprzy model dzieląc na zbiór testowy i terningowy.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import make_pipeline
from sklearn import model_selection

seed=123
kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=seed)

# %%
grid_1 = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), ElasticNet(alpha=1, random_state=seed)),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4],
                    'elasticnet__alpha': [0.01, 0.1, 1, 10]},
                    cv=kfold,
                    refit=True)
grid_1.fit(X, y)
grid_1.best_params_
# Out:
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1470.3391497521407, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1295.58614319286, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1315.2070549367, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1406.3078233924955, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1201.3016686109838, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 644.4208231603262, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 583.1706755258671, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 568.2264164515343, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 678.8586338838708, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 554.5291022460531, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 311.91977529977373, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 284.87424466830373, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 288.2661360472941, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 336.7016397800664, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 294.58009787085274, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1664.1631269846175, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1615.299131287671, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1588.0345805756167, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1563.876955040544, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1460.9262291287168, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 727.774972789399, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 661.1490317180226, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 670.2031415210815, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 756.2097684298126, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 632.1937510456783, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 357.88514991140954, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 327.601428084208, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 325.37739673298915, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 389.80509117049036, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 333.9228619471164, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1880.3631875655292, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1990.1020529796597, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1915.3695744128675, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1916.6325932056639, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1805.8564917813555, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 853.3763158005102, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 762.3455717457562, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 790.9792274650798, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 883.824747454076, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 728.2259959235446, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 421.65091733011593, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381.2470283138668, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 384.9515888125998, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 457.41262099420214, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 380.68482880891, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2360.6697175709082, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2467.174858806967, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2272.63452203103, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2431.0023730673965, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2202.0262099593556, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1070.8775826344279, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 956.9286557652043, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 979.6139574956321, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1085.3958455222764, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 879.795909642341, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 510.6047083314097, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 470.78271380773606, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 473.11968202024934, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 557.5839033445209, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 455.9475679786286, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2080.84832412168, tolerance: 4.100420313596492
#   model = cd_fast.enet_coordinate_descent(
# {'elasticnet__alpha': 0.1, 'polynomialfeatures__degree': 2}

# %%
grid_1.cv_results_['mean_test_score'].reshape(4, -1)
# Out:
# array([[0.70805942, 0.81680208, 0.74702819, 0.63462343],
#        [0.70014515, 0.83003047, 0.73343859, 0.63043122],
#        [0.66429641, 0.82359064, 0.75795199, 0.61636726],
#        [0.52367919, 0.80580758, 0.7581234 , 0.61997622]])

# %%
plt.matshow(grid_1.cv_results_['mean_test_score'].reshape(4, -1),
vmin=0, cmap="viridis")
plt.xlabel("elasticnet__alpha")
plt.ylabel("polynomialfeatures__degree")
plt.show()

# %%
grid_2 = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), Lasso(alpha=1, random_state=seed)),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4],
                    'lasso__alpha': [0.01, 0.1, 1, 10]},
                    cv=kfold,
                    refit=True)
grid_2.fit(X, y)
grid_2.best_params_
# Out:
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1459.026086266796, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1283.6082918170994, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1310.2393314381459, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1420.4510190991336, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1204.0743093024362, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 669.57278201804, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 602.3141225480591, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 590.4914435126694, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 698.1019789848849, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 575.7381278679139, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 324.312729381457, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 294.404587045588, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 297.1222760413629, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 347.9355966309705, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304.5117273688819, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1699.4758954389001, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1633.7031267554405, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1653.5076132025342, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1612.2420396660075, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1493.0425711182043, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 765.6198093562252, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 689.699408169158, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 711.9462474579428, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 790.1906524607448, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 660.5176803591771, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 378.4410220242661, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 344.96012111329276, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 341.2958687339817, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 410.12656454700357, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 347.3254585559283, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1991.3566405164981, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2131.176036512081, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2032.4352000428769, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2052.816317750307, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1923.9926160666841, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 906.6630942537762, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 812.2688677700196, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 851.990217195807, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 945.7113132320463, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 771.010067277697, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439.5616189410172, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 399.7921325524249, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 399.91955306554956, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 468.3519563798208, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 395.0206277864685, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2441.314920112495, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2555.7191589850036, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2363.0046110975018, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2163.2791279661355, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2265.1651068353663, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1149.3554174457865, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1046.9208020612352, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1050.0135019971929, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1125.928927036501, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 950.3063806756065, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 544.9906563474339, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 503.12524378509585, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 507.46661475641616, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 590.3391864280229, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 482.85731700822487, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2136.9698039171767, tolerance: 4.100420313596492
#   model = cd_fast.enet_coordinate_descent(
# {'lasso__alpha': 0.1, 'polynomialfeatures__degree': 2}

# %%
grid_2.cv_results_['mean_test_score'].reshape(4, -1)

plt.matshow(grid_2.cv_results_['mean_test_score'].reshape(4, -1),
vmin=0, cmap="viridis")
plt.xlabel("lasso__alpha")
plt.ylabel("polynomialfeatures__degree")
plt.show()

# %%
grid_3 = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), Ridge(alpha=1, random_state=seed)),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4],
                    'ridge__alpha': [0.01, 0.1, 1, 10]},
                    cv=kfold,
                    refit=True)
grid_3.fit(X, y)
grid_3.best_params_
# Out:
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.05096e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.92044e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.05096e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.92044e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.05096e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.92044e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.05096e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.92044e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# {'polynomialfeatures__degree': 2, 'ridge__alpha': 0.01}

# %%
grid_3.cv_results_['mean_test_score'].reshape(4, -1)

plt.matshow(grid_3.cv_results_['mean_test_score'].reshape(4, -1),
vmin=0, cmap="viridis")
plt.xlabel("ridge__alpha")
plt.ylabel("polynomialfeatures__degree")
plt.show()

# %%
grid_4 = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), linear_model.LinearRegression()),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4]},
                    cv=kfold,
                    refit=True)
grid_4.fit(X, y)
grid_4.best_params_
# Out:
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1459.026086266796, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1283.6082918170994, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1310.2393314381459, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1420.4510190991336, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1204.0743093024362, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 669.57278201804, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 602.3141225480591, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 590.4914435126694, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 698.1019789848849, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 575.7381278679139, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 324.312729381457, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 294.404587045588, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 297.1222760413629, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 347.9355966309705, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304.5117273688819, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1699.4758954389001, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1633.7031267554405, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1653.5076132025342, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1612.2420396660075, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1493.0425711182043, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 765.6198093562252, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 689.699408169158, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 711.9462474579428, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 790.1906524607448, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 660.5176803591771, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 378.4410220242661, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 344.96012111329276, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 341.2958687339817, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 410.12656454700357, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 347.3254585559283, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1991.3566405164981, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2131.176036512081, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2032.4352000428769, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2052.816317750307, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1923.9926160666841, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 906.6630942537762, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 812.2688677700196, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 851.990217195807, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 945.7113132320463, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 771.010067277697, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439.5616189410172, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 399.7921325524249, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 399.91955306554956, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 468.3519563798208, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 395.0206277864685, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2441.314920112495, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2555.7191589850036, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2363.0046110975018, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2163.2791279661355, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2265.1651068353663, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1149.3554174457865, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1046.9208020612352, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1050.0135019971929, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1125.928927036501, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 950.3063806756065, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 544.9906563474339, tolerance: 3.4242486895604394
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 503.12524378509585, tolerance: 3.142356865753425
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 507.46661475641616, tolerance: 3.079096421917808
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 590.3391864280229, tolerance: 3.4631412164383564
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 482.85731700822487, tolerance: 3.2808352493150683
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2136.9698039171767, tolerance: 4.100420313596492
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.05096e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.92044e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.05096e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.92044e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.05096e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.92044e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=1.05096e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:187: LinAlgWarning: Ill-conditioned matrix (rcond=6.92044e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True,
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# {'polynomialfeatures__degree': 2}

# %%
grid_4.cv_results_['mean_test_score'].reshape(4, -1)

plt.matshow(grid_4.cv_results_['mean_test_score'].reshape(4, -1),
vmin=0, cmap="viridis")
plt.xlabel("linear regression")
plt.ylabel("polynomialfeatures__degree")
plt.show()

# %%
from sklearn import  metrics

X_test=boston_X_test
y_test=boston_y_test

models = []
models.append(('ElasticNet', grid_1.best_estimator_))
models.append(('Lasso', grid_2.best_estimator_))
models.append(('Ridge', grid_3.best_estimator_))
models.append(('LR', grid_4.best_estimator_))

r2 = []
explained_variance_score = []
median_absolute_error = []
mean_squared_error = []
mean_absolute_error = []
for name, model in models:
    print(name)
    print("R^2: {}".format(metrics.r2_score(y_test, model.predict(X_test)) ))
    print("Explained variance score: {}".format( metrics.explained_variance_score(y_test, model.predict(X_test)) ))
    print("Median absolute error: {}".format( metrics.median_absolute_error(y_test, model.predict(X_test)) ))
    print("Mean squared error: {}".format( metrics.mean_squared_error(y_test, model.predict(X_test)) ))
    print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y_test, model.predict(X_test)) ))
    r2.append(metrics.r2_score(y_test, model.predict(X_test)))
    explained_variance_score.append(metrics.explained_variance_score(y_test, model.predict(X_test)))
    median_absolute_error.append( metrics.median_absolute_error(y_test, model.predict(X_test)))
    mean_squared_error.append(metrics.mean_squared_error(y_test, model.predict(X_test)))
    mean_absolute_error.append(metrics.mean_absolute_error(y_test, model.predict(X_test)))
# Out:
# ElasticNet
# R^2: -1.2894183199282097
# Explained variance score: -1.2715409278403205
# Median absolute error: 3.5151830600257927
# Mean squared error: 43.18506882697383
# Mean absolute errors: 4.829785092668605
# Lasso
# R^2: -1.3405620930677804
# Explained variance score: -1.3336502428326442
# Median absolute error: 3.6534388293894438
# Mean squared error: 44.149788705328234
# Mean absolute errors: 4.883117498278221
# Ridge
# R^2: -2.084504574498415
# Explained variance score: -1.8561486256399062
# Median absolute error: 2.622454485385683
# Mean squared error: 58.18270133830616
# Mean absolute errors: 4.910184983509465
# LR
# R^2: -3.4407949207295703
# Explained variance score: -2.7291053937678043
# Median absolute error: 3.38043874502182
# Mean squared error: 83.76627051022983
# Mean absolute errors: 5.7799199037551885

# %%
import pandas as pd
d = {'r2': r2, 
     'explained_variance_score': explained_variance_score, 
     'median_absolute_error': median_absolute_error,
     'mean_squared_error' : mean_squared_error,
     'mean_absolute_error' : mean_absolute_error,
    }
df = pd.DataFrame(data=d)
df.insert(loc=0, column='Method', value=['ElasticNet', 'Lasso', 'Ridge', 'LR'])#,'Lasso','Ridge','LR'])
df
# Out:
#        Method        r2  explained_variance_score  median_absolute_error  \
# 0  ElasticNet -1.289418                 -1.271541               3.515183
# 1       Lasso -1.340562                 -1.333650               3.653439
# 2       Ridge -2.084505                 -1.856149               2.622454
# 3          LR -3.440795                 -2.729105               3.380439
#
#    mean_squared_error  mean_absolute_error
# 0           43.185069             4.829785
# 1           44.149789             4.883117
# 2           58.182701             4.910185
# 3           83.766271             5.779920
