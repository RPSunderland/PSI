# %% [markdown]
# # Lasso Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn import linear_model
import scipy.stats as stats
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection

# %% [markdown]
# Rozważmy następujący zbiór punktów:

# %%
true_fun = lambda X: np.cos(1.5 * np.pi * X)
n_samples=20
x = np.sort(np.random.rand(n_samples))
y = true_fun(x) + np.random.randn(n_samples) * 0.1
x=np.vstack(x)

# %% [markdown]
# # Przykład
# Proszę wykonać regresję (Ridge Regression) na powyższym zbiorze danych

# %%
clf = Lasso(alpha=1.0)
clf.fit(x, y) 

x_plot = np.vstack(np.linspace(0, 1, 20))
plt.plot(x_plot, clf.predict(x_plot), color='blue',linewidth=3)
plt.plot(x, y, 'ok');
plt.show()

# %% [markdown]
# ## Regresja liniowa

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 2
# LR degree 20

# %% [markdown]
# # Zadanie
# Proszę wykonać
# * regresję dla wielomianów o stopniu **20**
# * regresję (Lasso Regression) dla wielomianów o stopniu **20** oraz
#    * alpha = 1
#    * alpha = 10 000
#    * alpha = 0.0001

# %%
models = []
predicts = []
names = []
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))
models.append(('Lasso degree 20, alpha=1', make_pipeline(PolynomialFeatures(20), Lasso(alpha=1)) ))
models.append(('Lasso degree 20, alpha=10000', make_pipeline(PolynomialFeatures(20), Lasso(alpha=10000)) ))
models.append(('Lasso degree 20, alpha=0.0001', make_pipeline(PolynomialFeatures(20), Lasso(alpha=0.0001)) ))  

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
plt.plot(x, y, 'ok');
for i in range(len(models)):
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.045863144682565, tolerance: 0.0008411115965744646
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr alpha.

# %%
from sklearn.model_selection import GridSearchCV

seed=123
kfold = model_selection.KFold(n_splits=10, random_state=seed)
scoring = 'neg_mean_absolute_error'
results = []


grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=3), Lasso()), param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7], 'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000]},
                    cv=kfold,
                    refit=False)
grid.fit(x, y)
grid.best_params_
# Out:
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009551906963983781, tolerance: 0.0008352874517632044
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0042794257508121936, tolerance: 0.0007846193738055703
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002795032781827411, tolerance: 0.0007747485769997969
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003094277684582314, tolerance: 0.0007714271519737148
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000786046598823753, tolerance: 0.0007783056711608648
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007700979153669185, tolerance: 0.000569675079771951
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0010946424460490378, tolerance: 0.000569675079771951
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001129692424487655, tolerance: 0.000569675079771951
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0011384551906240825, tolerance: 0.000569675079771951
#   model = cd_fast.enet_coordinate_descent(
# {'lasso__alpha': 0.001, 'polynomialfeatures__degree': 4}

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr <tt>alpha</tt> za pomocą metody <tt>GridSearchCV</tt> dla danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.
#
# *  policz r_square score.

# %%
import pandas as pd
df_adv = pd.read_csv('https://raw.githubusercontent.com/przem85/bootcamp/master/statistics/Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=3), Lasso()), 
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7], 
                                'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000]},
                    cv=kfold,
                    refit=False)
grid.fit(X, y)
best_params = grid.best_params_
best_params
# Out:
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.688982640633487, tolerance: 0.4850155777777778
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.479443981337834, tolerance: 0.49490757777777783
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.47481142254558, tolerance: 0.4737236444444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.417114137154726, tolerance: 0.4892888611111112
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.216767905650904, tolerance: 0.5011647277777779
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.871190020036433, tolerance: 0.49092654999999996
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.021229111523398, tolerance: 0.4691661944444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.635698700133652, tolerance: 0.4929196611111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.057105883620444, tolerance: 0.5036832
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.68478549270665, tolerance: 0.4727931111111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.977319225252725, tolerance: 0.4850155777777778
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.339253048180762, tolerance: 0.49490757777777783
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.634042535669067, tolerance: 0.4737236444444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.837287187176557, tolerance: 0.4892888611111112
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.469348862205955, tolerance: 0.5011647277777779
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.38124918229735, tolerance: 0.49092654999999996
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.090062724306009, tolerance: 0.4691661944444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.624211835966396, tolerance: 0.4929196611111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.87887411362118, tolerance: 0.5036832
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.932572048213572, tolerance: 0.4727931111111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.825913945258527, tolerance: 0.4850155777777778
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.98569554833586, tolerance: 0.49490757777777783
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.314326581703657, tolerance: 0.4737236444444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.491687145491582, tolerance: 0.4892888611111112
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.44321740023926, tolerance: 0.5011647277777779
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.222944165063417, tolerance: 0.49092654999999996
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.118557855453387, tolerance: 0.4691661944444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65.07504295740729, tolerance: 0.5036832
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.55481608405767, tolerance: 0.4727931111111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57.02950965102521, tolerance: 0.4850155777777778
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.01514206957191, tolerance: 0.49490757777777783
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57.57377806513664, tolerance: 0.4737236444444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.00351991665059, tolerance: 0.4892888611111112
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.87318822411477, tolerance: 0.5011647277777779
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.590717873707874, tolerance: 0.49092654999999996
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.946905920816576, tolerance: 0.4691661944444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.74203136907774, tolerance: 0.4929196611111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.695861511728154, tolerance: 0.5036832
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.01260365979495, tolerance: 0.4727931111111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105.48870032719462, tolerance: 0.4850155777777778
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108.71156801023288, tolerance: 0.49490757777777783
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108.65307680798476, tolerance: 0.4737236444444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105.02808372993515, tolerance: 0.4892888611111112
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109.8085925685989, tolerance: 0.5011647277777779
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107.07614002003903, tolerance: 0.49092654999999996
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.42376232651763, tolerance: 0.4691661944444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97.83976021834211, tolerance: 0.4929196611111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113.04376277886648, tolerance: 0.5036832
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106.84255164677033, tolerance: 0.4727931111111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96.12768258550588, tolerance: 0.4850155777777778
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100.4643076067328, tolerance: 0.49490757777777783
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102.14476829988804, tolerance: 0.4737236444444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98.60274450511157, tolerance: 0.4892888611111112
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101.30717731249838, tolerance: 0.5011647277777779
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95.25832171294006, tolerance: 0.49092654999999996
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.66681770533586, tolerance: 0.4691661944444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89.98717896973889, tolerance: 0.4929196611111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104.08645074919949, tolerance: 0.5036832
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97.26910702307464, tolerance: 0.4727931111111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88.93912411407501, tolerance: 0.4850155777777778
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92.03233017629277, tolerance: 0.49490757777777783
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.04190899171216, tolerance: 0.4737236444444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.64428133431439, tolerance: 0.4892888611111112
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93.48352670682743, tolerance: 0.5011647277777779
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87.30390285861297, tolerance: 0.49092654999999996
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83.51938782048214, tolerance: 0.4691661944444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.99720141033016, tolerance: 0.4929196611111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96.71406310344638, tolerance: 0.5036832
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89.34302599024196, tolerance: 0.4727931111111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76.62478922812991, tolerance: 0.4850155777777778
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.25667654222515, tolerance: 0.49490757777777783
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.08942738083425, tolerance: 0.4737236444444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78.38033138451215, tolerance: 0.4892888611111112
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.07276535446864, tolerance: 0.5011647277777779
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.11740866306218, tolerance: 0.49092654999999996
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.35540829170749, tolerance: 0.4691661944444444
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 69.6579349972789, tolerance: 0.4929196611111111
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84.61601530263043, tolerance: 0.5036832
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79.15138417636423, tolerance: 0.4727931111111111
#   model = cd_fast.enet_coordinate_descent(
# {'lasso__alpha': 0.1, 'polynomialfeatures__degree': 3}

# %%
from sklearn import  metrics

best_model = make_pipeline(PolynomialFeatures(degree=best_params['polynomialfeatures__degree']), Lasso(alpha=best_params['lasso__alpha']))
best_model.fit(X, y)
y_pred = best_model.predict(X)
r2 = metrics.r2_score(y, y_pred)
print(r2)
# Out:
# 0.9914869731209236
# c:\Users\rafal\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.574718653360648, tolerance: 0.541714875
#   model = cd_fast.enet_coordinate_descent(
