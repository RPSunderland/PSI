# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x + p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_1 = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_1, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_2 = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_2, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack((np.ones_like(x), x, x**2, x**3)).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

# %%
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_3 = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_3, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack((np.ones_like(x), x, x**2, x**3, x**4)).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

# %%
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_4 = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_4, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack((np.ones_like(x), x, x**2, x**3, x**4, x**5)).T
p5 = np.linalg.lstsq(M5, y, rcond=None)

# %%
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_5 = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_5, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_1, 'green', label='linear');
plt.plot(x_f_lr, y_f_lr_2, 'blue', label='quadratic');
plt.plot(x_f_lr, y_f_lr_3, 'violet', label='cubic');
plt.plot(x_f_lr, y_f_lr_4, 'orange', label='quartic');
plt.plot(x_f_lr, y_f_lr_5, 'black', label='quintic');
plt.plot(x, y, 'ok', ms=3, color='r', label='data');
plt.legend()
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res5 = sm.OLS(y, M5).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.498
# Dependent Variable: y                AIC:                644.2300
# Date:               2024-04-08 10:21 BIC:                649.4403
# No. Observations:   100              Log-Likelihood:     -320.11
# Df Model:           1                F-statistic:        99.28
# Df Residuals:       98               Prob (F-statistic): 1.45e-16
# R-squared:          0.503            Scale:              36.040
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.7880     1.2406   -3.0534   0.0029   -6.2499   -1.3261
# x1         6.8778     0.6903    9.9637   0.0000    5.5079    8.2476
# -----------------------------------------------------------------
# Omnibus:              29.728       Durbin-Watson:          2.290
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       48.401
# Skew:                 1.300        Prob(JB):               0.000
# Kurtosis:             5.204        Condition No.:          5
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.809
# Dependent Variable: y                AIC:                548.7720
# Date:               2024-04-08 10:21 BIC:                556.5875
# No. Observations:   100              Log-Likelihood:     -271.39
# Df Model:           2                F-statistic:        210.2
# Df Residuals:       97               Prob (F-statistic): 5.44e-36
# R-squared:          0.813            Scale:              13.740
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const        7.1459    1.1549   6.1877  0.0000    4.8538    9.4379
# x1         -14.7060    1.7585  -8.3629  0.0000  -18.1961  -11.2159
# x2           7.1247    0.5632  12.6513  0.0000    6.0069    8.2424
# -----------------------------------------------------------------
# Omnibus:              3.027        Durbin-Watson:           2.170
# Prob(Omnibus):        0.220        Jarque-Bera (JB):        2.845
# Skew:                 0.412        Prob(JB):                0.241
# Kurtosis:             2.929        Condition No.:           26
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -23.3505
# Date:               2024-04-08 10:21 BIC:                -7.7195
# No. Observations:   100              Log-Likelihood:     17.675
# Df Model:           5                F-statistic:        3.249e+04
# Df Residuals:       94               Prob (F-statistic): 1.67e-150
# R-squared:          0.999            Scale:              0.043739
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -0.9505     0.1419   -6.6970   0.0000   -1.2323   -0.6687
# x1          9.6435     0.8782   10.9809   0.0000    7.8998   11.3872
# x2         -1.9349     1.7772   -1.0887   0.2791   -5.4636    1.5938
# x3         -4.6611     1.4941   -3.1196   0.0024   -7.6277   -1.6944
# x4          1.7930     0.5461    3.2831   0.0014    0.7087    2.8773
# x5          0.0334     0.0719    0.4648   0.6431   -0.1094    0.1762
# ------------------------------------------------------------------
# Omnibus:              3.858         Durbin-Watson:           2.066
# Prob(Omnibus):        0.145         Jarque-Bera (JB):        3.803
# Skew:                 -0.435        Prob(JB):                0.149
# Kurtosis:             2.603         Condition No.:           9969
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()
Res5F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)+I(x**5)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     99.28
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           1.45e-16
# Time:                        10:23:02   Log-Likelihood:                -320.11
# No. Observations:                 100   AIC:                             644.2
# Df Residuals:                      98   BIC:                             649.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.7880      1.241     -3.053      0.003      -6.250      -1.326
# x              6.8778      0.690      9.964      0.000       5.508       8.248
# ==============================================================================
# Omnibus:                       29.728   Durbin-Watson:                   2.290
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.401
# Skew:                           1.300   Prob(JB):                     3.09e-11
# Kurtosis:                       5.204   Cond. No.                         4.65
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.813
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     210.2
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           5.44e-36
# Time:                        10:23:02   Log-Likelihood:                -271.39
# No. Observations:                 100   AIC:                             548.8
# Df Residuals:                      97   BIC:                             556.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.1459      1.155      6.188      0.000       4.854       9.438
# x            -14.7060      1.758     -8.363      0.000     -18.196     -11.216
# I(x ** 2)      7.1247      0.563     12.651      0.000       6.007       8.242
# ==============================================================================
# Omnibus:                        3.027   Durbin-Watson:                   2.170
# Prob(Omnibus):                  0.220   Jarque-Bera (JB):                2.845
# Skew:                           0.412   Prob(JB):                        0.241
# Kurtosis:                       2.929   Cond. No.                         26.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.249e+04
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):          1.67e-150
# Time:                        10:23:02   Log-Likelihood:                 17.675
# No. Observations:                 100   AIC:                            -23.35
# Df Residuals:                      94   BIC:                            -7.719
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9505      0.142     -6.697      0.000      -1.232      -0.669
# x              9.6435      0.878     10.981      0.000       7.900      11.387
# I(x ** 2)     -1.9349      1.777     -1.089      0.279      -5.464       1.594
# I(x ** 3)     -4.6611      1.494     -3.120      0.002      -7.628      -1.694
# I(x ** 4)      1.7930      0.546      3.283      0.001       0.709       2.877
# I(x ** 5)      0.0334      0.072      0.465      0.643      -0.109       0.176
# ==============================================================================
# Omnibus:                        3.858   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.145   Jarque-Bera (JB):                3.803
# Skew:                          -0.435   Prob(JB):                        0.149
# Kurtosis:                       2.603   Cond. No.                     9.97e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.97e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
