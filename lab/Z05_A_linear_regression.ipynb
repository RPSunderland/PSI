# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x + p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_1 = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_1, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_2 = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_2, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack((np.ones_like(x), x, x**2, x**3)).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

# %%
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_3 = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_3, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack((np.ones_like(x), x, x**2, x**3, x**4)).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

# %%
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_4 = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_4, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack((np.ones_like(x), x, x**2, x**3, x**4, x**5)).T
p5 = np.linalg.lstsq(M5, y, rcond=None)

# %%
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_5 = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_5, 'g');
plt.plot(x, y, 'ok', ms=3, color='r');
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_1, 'green', label='linear');
plt.plot(x_f_lr, y_f_lr_2, 'blue', label='quadratic');
plt.plot(x_f_lr, y_f_lr_3, 'violet', label='cubic');
plt.plot(x_f_lr, y_f_lr_4, 'orange', label='quartic');
plt.plot(x_f_lr, y_f_lr_5, 'black', label='quintic');
plt.plot(x, y, 'ok', ms=3, color='r', label='data');
plt.legend()
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.501
# Dependent Variable: y                AIC:                624.6324
# Date:               2024-04-13 20:03 BIC:                629.8427
# No. Observations:   100              Log-Likelihood:     -310.32
# Df Model:           1                F-statistic:        100.6
# Df Residuals:       98               Prob (F-statistic): 1.05e-16
# R-squared:          0.506            Scale:              29.626
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.0803     1.0878   -2.8318   0.0056   -5.2390   -0.9217
# x1         6.3864     0.6369   10.0276   0.0000    5.1225    7.6502
# -----------------------------------------------------------------
# Omnibus:             41.026       Durbin-Watson:          1.839
# Prob(Omnibus):       0.000        Jarque-Bera (JB):       103.602
# Skew:                1.505        Prob(JB):               0.000
# Kurtosis:            6.976        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.794
# Dependent Variable: y                AIC:                537.1774
# Date:               2024-04-13 20:03 BIC:                544.9929
# No. Observations:   100              Log-Likelihood:     -265.59
# Df Model:           2                F-statistic:        191.9
# Df Residuals:       97               Prob (F-statistic): 1.93e-34
# R-squared:          0.798            Scale:              12.236
# -------------------------------------------------------------------
#          Coef.     Std.Err.      t      P>|t|     [0.025     0.975]
# -------------------------------------------------------------------
# const     6.6674     1.0798    6.1746   0.0000     4.5243    8.8106
# x1      -12.9270     1.6812   -7.6891   0.0000   -16.2637   -9.5903
# x2        6.4488     0.5445   11.8442   0.0000     5.3682    7.5294
# -----------------------------------------------------------------
# Omnibus:              12.488       Durbin-Watson:          2.036
# Prob(Omnibus):        0.002        Jarque-Bera (JB):       13.292
# Skew:                 0.779        Prob(JB):               0.001
# Kurtosis:             3.872        Condition No.:          25
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.990
# Dependent Variable: y                AIC:                236.6481
# Date:               2024-04-13 20:03 BIC:                247.0688
# No. Observations:   100              Log-Likelihood:     -114.32
# Df Model:           3                F-statistic:        3235.
# Df Residuals:       96               Prob (F-statistic): 2.89e-96
# R-squared:          0.990            Scale:              0.60015
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -4.2783    0.3477  -12.3062  0.0000   -4.9684   -3.5883
# x1         27.7148    1.0082   27.4892  0.0000   25.7135   29.7160
# x2        -26.6353    0.7722  -34.4938  0.0000  -28.1681  -25.1026
# x3          7.2844    0.1679   43.3774  0.0000    6.9510    7.6177
# -----------------------------------------------------------------
# Omnibus:              14.094       Durbin-Watson:          2.100
# Prob(Omnibus):        0.001        Jarque-Bera (JB):       15.426
# Skew:                 0.856        Prob(JB):               0.000
# Kurtosis:             3.877        Condition No.:          182
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -41.6779
# Date:               2024-04-13 20:03 BIC:                -28.6520
# No. Observations:   100              Log-Likelihood:     25.839
# Df Model:           4                F-statistic:        3.998e+04
# Df Residuals:       95               Prob (F-statistic): 2.68e-152
# R-squared:          0.999            Scale:              0.036759
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.9170     0.1228    -7.4681   0.0000   -1.1608   -0.6732
# x1         9.3322     0.5402    17.2768   0.0000    8.2598   10.4045
# x2        -1.1236     0.6918    -1.6242   0.1077   -2.4970    0.2498
# x3        -5.4235     0.3338   -16.2486   0.0000   -6.0861   -4.7608
# x4         2.0691     0.0539    38.3711   0.0000    1.9621    2.1762
# ------------------------------------------------------------------
# Omnibus:               0.236        Durbin-Watson:           2.015
# Prob(Omnibus):         0.889        Jarque-Bera (JB):        0.172
# Skew:                  0.099        Prob(JB):                0.918
# Kurtosis:              2.957        Condition No.:           1377
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -39.6877
# Date:               2024-04-13 20:03 BIC:                -24.0567
# No. Observations:   100              Log-Likelihood:     25.844
# Df Model:           5                F-statistic:        3.165e+04
# Df Residuals:       94               Prob (F-statistic): 5.70e-150
# R-squared:          0.999            Scale:              0.037147
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -0.9274     0.1640   -5.6559   0.0000   -1.2529   -0.6018
# x1          9.4091     0.9680    9.7204   0.0000    7.4872   11.3311
# x2         -1.2845     1.8149   -0.7078   0.4808   -4.8880    2.3189
# x3         -5.2883     1.4468   -3.6551   0.0004   -8.1611   -2.4156
# x4          2.0203     0.5119    3.9470   0.0002    1.0040    3.0366
# x5          0.0064     0.0661    0.0960   0.9237   -0.1250    0.1377
# ------------------------------------------------------------------
# Omnibus:               0.235        Durbin-Watson:           2.012
# Prob(Omnibus):         0.889        Jarque-Bera (JB):        0.181
# Skew:                  0.101        Prob(JB):                0.913
# Kurtosis:              2.949        Condition No.:           9983
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()
Res3F = smf.ols('y ~ x+I(x**2)+I(x**3)', df).fit()
Res4F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)', df).fit()
Res5F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)+I(x**5)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.506
# Model:                            OLS   Adj. R-squared:                  0.501
# Method:                 Least Squares   F-statistic:                     100.6
# Date:                Sat, 13 Apr 2024   Prob (F-statistic):           1.05e-16
# Time:                        20:04:36   Log-Likelihood:                -310.32
# No. Observations:                 100   AIC:                             624.6
# Df Residuals:                      98   BIC:                             629.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.0803      1.088     -2.832      0.006      -5.239      -0.922
# x              6.3864      0.637     10.028      0.000       5.122       7.650
# ==============================================================================
# Omnibus:                       41.026   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.602
# Skew:                           1.505   Prob(JB):                     3.18e-23
# Kurtosis:                       6.976   Cond. No.                         4.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     191.9
# Date:                Sat, 13 Apr 2024   Prob (F-statistic):           1.93e-34
# Time:                        20:04:36   Log-Likelihood:                -265.59
# No. Observations:                 100   AIC:                             537.2
# Df Residuals:                      97   BIC:                             545.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.6674      1.080      6.175      0.000       4.524       8.811
# x            -12.9270      1.681     -7.689      0.000     -16.264      -9.590
# I(x ** 2)      6.4488      0.544     11.844      0.000       5.368       7.529
# ==============================================================================
# Omnibus:                       12.488   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.292
# Skew:                           0.779   Prob(JB):                      0.00130
# Kurtosis:                       3.872   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     3235.
# Date:                Sat, 13 Apr 2024   Prob (F-statistic):           2.89e-96
# Time:                        20:04:36   Log-Likelihood:                -114.32
# No. Observations:                 100   AIC:                             236.6
# Df Residuals:                      96   BIC:                             247.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -4.2783      0.348    -12.306      0.000      -4.968      -3.588
# x             27.7148      1.008     27.489      0.000      25.713      29.716
# I(x ** 2)    -26.6353      0.772    -34.494      0.000     -28.168     -25.103
# I(x ** 3)      7.2844      0.168     43.377      0.000       6.951       7.618
# ==============================================================================
# Omnibus:                       14.094   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.426
# Skew:                           0.856   Prob(JB):                     0.000447
# Kurtosis:                       3.877   Cond. No.                         182.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.998e+04
# Date:                Sat, 13 Apr 2024   Prob (F-statistic):          2.68e-152
# Time:                        20:04:36   Log-Likelihood:                 25.839
# No. Observations:                 100   AIC:                            -41.68
# Df Residuals:                      95   BIC:                            -28.65
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9170      0.123     -7.468      0.000      -1.161      -0.673
# x              9.3322      0.540     17.277      0.000       8.260      10.405
# I(x ** 2)     -1.1236      0.692     -1.624      0.108      -2.497       0.250
# I(x ** 3)     -5.4235      0.334    -16.249      0.000      -6.086      -4.761
# I(x ** 4)      2.0691      0.054     38.371      0.000       1.962       2.176
# ==============================================================================
# Omnibus:                        0.236   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.889   Jarque-Bera (JB):                0.172
# Skew:                           0.099   Prob(JB):                        0.918
# Kurtosis:                       2.957   Cond. No.                     1.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.165e+04
# Date:                Sat, 13 Apr 2024   Prob (F-statistic):          5.70e-150
# Time:                        20:04:36   Log-Likelihood:                 25.844
# No. Observations:                 100   AIC:                            -39.69
# Df Residuals:                      94   BIC:                            -24.06
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9274      0.164     -5.656      0.000      -1.253      -0.602
# x              9.4091      0.968      9.720      0.000       7.487      11.331
# I(x ** 2)     -1.2845      1.815     -0.708      0.481      -4.888       2.319
# I(x ** 3)     -5.2883      1.447     -3.655      0.000      -8.161      -2.416
# I(x ** 4)      2.0203      0.512      3.947      0.000       1.004       3.037
# I(x ** 5)      0.0064      0.066      0.096      0.924      -0.125       0.138
# ==============================================================================
# Omnibus:                        0.235   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.889   Jarque-Bera (JB):                0.181
# Skew:                           0.101   Prob(JB):                        0.913
# Kurtosis:                       2.949   Cond. No.                     9.98e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.98e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
