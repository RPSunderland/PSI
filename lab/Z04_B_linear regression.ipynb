# %% [markdown]
# # Regresja liniowa
#
# Naszym Celem jest empityczne sprawdzenie twierdzenia:
#
# Niech $A \in \mathbb{R}^{N\times K}$ będzie macierzą która przekształca $\mathbb{R}^{K}$ w $\mathbb{R}^N$, i niech $y \in \mathbb{R}^{K}$.
#
# Wtedy punkt $x_0 \in \mathbb{R}^K$ spełnia
#
# $$
# x_0 = \mathrm{argmin} \{ x \in \mathbb{R}^K   \colon \| Ax - y \|^2 \}
# $$
#
# wtedy i tylko wtedy gdy
#
# $$
# A^TA x_0 = A^Ty.
# $$

# %%
import numpy as np
import scipy.stats as st
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę wykres funkcji w kształcie
#
# $
# f(x)=x^2
# $
#
# na odcinku $[0,3]$ i go narysować.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: (x**2)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)=x^2$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
# We create the model.
lr = lm.LinearRegression()
# We train the model on our training dataset.
lr.fit(x[:, np.newaxis], y);
print(lr.coef_)
print(lr.intercept_)
# Out:
# [2.87856916]
# -1.654353473571966

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr = lambda x: lr.coef_ * x +lr.intercept_

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Teraz możemy wykonać predykcję dla punktu
# $$
# x_0 = 1.5
# $$

# %%
point = np.array([1.5])
y_point = lr.predict(point[:, np.newaxis])

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.plot(point, y_point, 'or', ms=10);
plt.show()

# %% [markdown]
# Możemy wypisać miarę dopasowania $R^2$. Narazie nie wnikamy w to co ona oznacza.

# %%
from sklearn.metrics import r2_score
print(lr.score(x[:, np.newaxis], y))
print(r2_score(lr.predict(x[:, np.newaxis]), y))
# Out:
# 0.9076172239782524
# 0.8982139457239287

# %% [markdown]
# # Zadanie 1
# Stwórz macierz postaci:
# $$
# A=\begin{bmatrix}
# x_1 & 1\\
# \ddots & \ddots\\
# x_n & 1\\
# \end{bmatrix}
# $$
#
# i rozwiąż równanie
#
# $$
# A^TA x = A^Ty.
# $$
#
# gdzie (x,y) to nasz zbiór treningowy.
#
# Użyj funkcji <tt>linalg.solve</tt>.

# %%
deg=1
xx=np.vander(x, deg + 1)
xx
# Out:
# array([[0.2, 1. ],
#        [0.5, 1. ],
#        [0.8, 1. ],
#        [0.9, 1. ],
#        [1.3, 1. ],
#        [1.7, 1. ],
#        [2.1, 1. ],
#        [2.7, 1. ]])

# %%
np.linalg.solve(np.dot(xx.T, xx), np.dot(xx.T, y))
# Out:
# array([ 2.87856916, -1.65435347])

# %% [markdown]
# # Zadanie 2
# Zapoznaj się z funkcją <tt>optimize.fmin_cg</tt>
# https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.optimize.fmin_cg.html
# i znajdż minum funkcji
#
# $$
# f(x,y) = (x+1)^2+y^2
# $$

# %%
from scipy import optimize

def f(params):
    x, y = params
    return (x + 1) ** 2 + y ** 2

result = optimize.fmin_cg(f, [0, 0])
result
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 9
#          Gradient evaluations: 3
# array([-1.00000001e+00, -7.45058060e-09])

# %% [markdown]
# # Zadanie 3
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error}(a,b;(x,y)) =  \sum_{i=1}^{n} ( y_i - (ax_i+b) )^2.
# $$

# %%
def compute_error(params, data):
    a, b = params
    x, y = data
    return np.sum((a * x + b - y) ** 2)

compute_error([2.87856916, -1.65435347], [x, y])
# Out:
# 4.229729108568643

# %% [markdown]
# # Zadanie 4
# Zminimalizuj funkcją $\mathrm{compute\_error}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
result = optimize.fmin_cg(compute_error, [0, 0], args=([x, y],))
# Out:
# Optimization terminated successfully.
#          Current function value: 4.229729
#          Iterations: 14
#          Function evaluations: 66
#          Gradient evaluations: 22

# %% [markdown]
# # Zadanie 5
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error\_1}(a,b;(x,y)) =  \sum_{i=1}^{n} |y_i - (ax_i+b)|.
# $$

# %%
def compute_error_2(params, data):
    a, b = params
    x, y = data
    return np.sum(np.abs(a * x + b - y))

# %% [markdown]
# # Zadanie 6
# Zminimalizuj funkcją $\mathrm{compute\_error\_1}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
result = optimize.fmin_cg(compute_error_2, [0, 0], args=([x, y],))
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.144499
#          Iterations: 4
#          Function evaluations: 181
#          Gradient evaluations: 58

# %% [markdown]
# # Zadanie 7
# Wykonaj dwie powyższe regresję na danych z wartością odstającą.

# %%
f = lambda x: (x)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))/5
y[1]=y[1]+10
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,12])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
points = np.column_stack((x,y))

# %%
x = points[:,0]
y = points[:,1]
deg=1
xx=np.vander(x, deg + 1)
xx
# Out:
# array([[0.2, 1. ],
#        [0.5, 1. ],
#        [0.8, 1. ],
#        [0.9, 1. ],
#        [1.3, 1. ],
#        [1.7, 1. ],
#        [2.1, 1. ],
#        [2.7, 1. ]])

# %%
np.linalg.solve(np.dot(xx.T, xx), np.dot(xx.T, y))
# Out:
# array([-0.47607015,  3.11630644])

# %%
import matplotlib.pyplot as plt

res1 = optimize.fmin_cg(compute_error, [0, 0], args=([x, y],))
res2 = optimize.fmin_cg(compute_error_2, [0, 0], args=([x, y],))
plt.plot(x, y, 'ok', ms=10, label='data')
plt.plot(x, res1[0] * x + res1[1], '-b', lw=2, label='compute_error')
plt.plot(x, res2[0] * x + res2[1], '-r', lw=2, label='compute_error_1')
plt.legend()
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 76.705535
#          Iterations: 3
#          Function evaluations: 18
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 10.788245
#          Iterations: 3
#          Function evaluations: 108
#          Gradient evaluations: 36
