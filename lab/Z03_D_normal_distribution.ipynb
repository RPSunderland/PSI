# %% [markdown]
# # 2-wymiarowy rozkład Normalny

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as rnd
import scipy.stats as stats
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę z rozkładu Normalnego
# $$
# m = [0,0]
# $$
#
# oraz
#
# $$
# \Sigma = [[4.40, -2.75], [-2.75,  5.50]]
# $$

# %%
mean_1 = np.array([0, 0])
cov_1 = np.array([[4.40, -2.75], [-2.75,  5.50]])
X1_rv = multivariate_normal(mean_1, cov_1)
X = X1_rv.rvs(1000)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (5, 5))
ax.scatter(X[:, 0], X[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
plt.show()

# %% [markdown]
# # Zadanie
# Proszę policzyć średnią oraz macierz kowariancji próbki.

# %%
means = X.mean(axis = 0)
cov = np.cov(X.T)

# %% [markdown]
# # Zadanie
# Proszę zdefiniować zmienną losową o razkładzie zadanym na podstawie empirycznej średniej i kowariancji oraz narysować na jednym wykresie:
#
# - próbkę
# - poziomice rozkładu normalnego

# %%
X_2, Y_2 = stats.multivariate_normal(means, cov).rvs(1000).T
plt.plot(X_2, Y_2, '.', markersize = 3)
x = np.linspace(-8, 8, 100)
y = np.linspace(-8, 8, 100)
x, y = np.meshgrid(x, y)
Z_2 = stats.multivariate_normal(means, cov).pdf(np.dstack([x, y]))
plt.contourf(x, y, Z_2, cmap = 'Greens')
plt.colorbar()
plt.show()

# %% [markdown]
# # Zadanie
# Policz wektory i wartości własne macierzy kowariancji. Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
plt.plot(X_2, Y_2, '.', markersize = 3)
plt.contourf(x, y, Z_2, cmap = 'Greens')
eigenvalues, eigenvectors = np.linalg.eig(cov)
eigenvectors = eigenvectors.T
plt.quiver(means[0], means[1], eigenvalues[0] * eigenvectors[0, 0], eigenvalues[0] * eigenvectors[0, 1], angles = 'xy', scale_units = 'xy', scale = 1, color = 'red') 
plt.quiver(means[0], means[1], eigenvalues[1] * eigenvectors[1, 0], eigenvalues[1] * eigenvectors[1, 1], angles = 'xy', scale_units = 'xy', scale = 1, color = 'red')
plt.show()

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę na kwadracie $[0,1] \times [0,1]$.
# Następnie proszę policzyć średnią oraz macierz kowariancji próbki.
#
# Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)
X_3, Y_3 = np.random.uniform(0, 1, 1000), np.random.uniform(0, 1, 1000)
mean = [X_3.mean(), Y_3.mean()]
cov = np.cov(X_3, Y_3)
Z_3 = multivariate_normal(mean, cov).pdf(np.dstack([X, Y]))
plt.plot(X_3, Y_3, '.', markersize = 3)
plt.contourf(X, Y, Z_3, cmap = 'Greens')
eigenvalues, eigenvectors = np.linalg.eig(cov)
eigenvectors = eigenvectors.T
plt.quiver(mean[0], mean[1], eigenvalues[0] * eigenvectors[0, 0], eigenvalues[0] * eigenvectors[0, 1], angles = 'xy', scale_units = 'xy', scale = 0.2, color = 'red') 
plt.quiver(mean[0], mean[1], eigenvalues[1] * eigenvectors[1, 0], eigenvalues[1] * eigenvectors[1, 1], angles = 'xy', scale_units = 'xy', scale = 0.2, color = 'red')
plt.show()
